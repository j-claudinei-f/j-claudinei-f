# %% [markdown]
# <a href="https://colab.research.google.com/github/j-claudinei-f/j-claudinei-f/blob/main/Carreira_Docente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Simulção Plano de Carreira Docentes Federais**

# %% [markdown]
# #**Proposta Andes de reajuste de 22.71% em três anos, com ideia de base ser salário de 20 horas**
#
#
# Desconsidere os cálculos e veja a planilha a seguir.

# %%
pi=3839.21*(1+22.71/100)

p=[[1,pi,2*pi,3.1*pi]]

for i in range(2,14):
 pi=pi*(5/100+1)
 p.append([i,pi,2*pi,3.1*pi])

# %%
import pandas as pd
Indice=['Probatório 1','Probatório 2','Assistente 1', 'Assistente 2','Adjunto 1','Adjunto 2','Adjunto 3','Adjunto 4','Associado 1','Associado 2','Associado 3','Associado 4','Titular']
df=pd.DataFrame(p,index=Indice,columns=['nível','20 horas','40 horas', 'DE'])
import matplotlib. pyplot as plt

print('Proposta carreira - steps de 5%, como peso 1, 2 e 3.1, partindo de 20 horas')
df
# Out:
# Proposta carreira - steps de 5%, como peso 1, 2 e 3.1, partindo de 20 horas
#               nível     20 horas      40 horas            DE
# Probatório 1      1  4711.094591   9422.189182  14604.393232
# Probatório 2      2  4946.649321   9893.298641  15334.612894
# Assistente 1      3  5193.981787  10387.963573  16101.343538
# Assistente 2      4  5453.680876  10907.361752  16906.410715
# Adjunto 1         5  5726.364920  11452.729839  17751.731251
# Adjunto 2         6  6012.683166  12025.366331  18639.317814
# Adjunto 3         7  6313.317324  12626.634648  19571.283704
# Adjunto 4         8  6628.983190  13257.966380  20549.847890
# Associado 1       9  6960.432350  13920.864699  21577.340284
# Associado 2      10  7308.453967  14616.907934  22656.207298
# Associado 3      11  7673.876666  15347.753331  23789.017663
# Associado 4      12  8057.570499  16115.140998  24978.468546
# Titular          13  8460.449024  16920.898047  26227.391974

# %% [markdown]
# #**Proposta do Governo de reajuste de 9% em 2025 e 3.5 em 2026, com alteração de carreira**
#
# Veja planilha abaixo.

# %%
import numpy as np
salarioatual=np.array([12191.60,12862.13,13376.61,13911.69,14468.14,18085.19,8748.19+10060.41,19560.93,20343.37,22377.72])
salarioatualAndes=np.array([12191.60,12862.13,13376.61,13911.69,14468.14,18085.19,8748.19+10060.41,19560.93,20343.37,22377.72])*(1+22.71/100)

Salario2025=salarioatual*(1+9/100)
Salario2026=salarioatual*(1+9/100)*(1+3.5/100)
Salario2025novapropsta=[salarioatual[0]*(1+9/100)] # Probatório
p=salarioatual[1]*(1+9/100)
Salario2025novapropsta.append(p) #Adjunto 1
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Adjunto 2
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Adjunto 3
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Adjunto 4
p=p*(1+23.5/100)
Salario2025novapropsta.append(p) #Associado 1
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Associado 2
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Associado 3
p=p*(1+4.5/100)
Salario2025novapropsta.append(p) #Associado 4
Salario2025novapropsta.append(salarioatual[9]*(1+9/100)) #Titular

Salario2026novapropsta=salarioatual*np.array([(1+9/100)*(1+3.5/100),1+13.3/100,1+14.3/100,1+15.5/100,1+16.7/100,1+14.3/100,1+15.4/100,1+16.5/100,1+17.6/100,1+17.61/100])
Proposta=[salarioatual,Salario2025,Salario2026,Salario2025novapropsta,Salario2026novapropsta,salarioatualAndes]

# %%
df=pd.DataFrame(Proposta,index=[2024,2025,2026,'2025-novo','2026-novo','2026-Proposta Andes'],columns=['Probatório','Adjunto 1','Adjunto 2','Adjunto 3','Adjunto 4','Associado 1','Associado 2','Associado 3','Associado 4','Titular'])

print(' Proposta carreira - com reajuste de 9% e 3.5%, com e sem mudança de steps')
df
# Out:
#  Proposta carreira - com reajuste de 9% e 3.5%, com e sem mudança de steps
#                       Probatório     Adjunto 1     Adjunto 2     Adjunto 3  \
# 2024                 12191.60000  12862.130000  13376.610000  13911.690000
# 2025                 13288.84400  14019.721700  14580.504900  15163.742100
# 2026                 13753.95354  14510.411959  15090.822572  15694.473073
# 2025-novo            13288.84400  14019.721700  14650.609176  15309.886589
# 2026-novo            13753.95354  14572.793290  15289.465230  16068.001950
# 2026-Proposta Andes  14960.31236  15783.119723  16414.438131  17071.034799
#
#                         Adjunto 4   Associado 1   Associado 2   Associado 3  \
# 2024                 14468.140000  18085.190000  18808.600000  19560.930000
# 2025                 15770.272600  19712.857100  20501.374000  21321.413700
# 2026                 16322.232141  20402.807099  21218.922090  22067.663179
# 2025-novo            15998.831486  19758.556885  20647.691945  21576.838083
# 2026-novo            16884.319380  20671.372170  21705.124400  22788.483450
# 2026-Proposta Andes  17753.854594  22192.336649  23080.033060  24003.217203
#
#                       Associado 4       Titular
# 2024                 20343.370000  22377.720000
# 2025                 22174.273300  24391.714800
# 2026                 22950.372865  25245.424818
# 2025-novo            22547.795796  24391.714800
# 2026-novo            23923.803120  26318.436492
# 2026-Proposta Andes  24963.349327  27459.700212
